# %% [markdown]
# Importing panadas and matlotlib Libraries and giving them a alias name

# %%
import pandas as pd

# %% [markdown]
# Reading CSV File

# %%
df=pd.read_csv("netflix_titles.csv")
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %% [markdown]
# Question #1: Convert dates into a proper date-time format of your choice

# %%
df['date_added'] = pd.to_datetime(df['date_added'])
df.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...

# %% [markdown]
# #Question #2: Finding seasons count from durations column

# %% [markdown]
# #Removing all  NaN values

# %%
df = df.dropna(how='any')

# %% [markdown]
# #adding new collomn in dataframe

# %%
season=df['duration'].str.find('Season')
df.head()
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin... 2021-09-24
# 8                                      United Kingdom 2021-09-24
# 9                                       United States 2021-09-24
# 12                            Germany, Czech Republic 2021-09-23
# 24                                              India 2021-09-21
#
#     release_year rating   duration  \
# 7           1993  TV-MA    125 min
# 8           2021  TV-14  9 Seasons
# 9           2021  PG-13    104 min
# 12          2021  TV-MA    127 min
# 24          1998  TV-14    166 min
#
#                                            listed_in  \
# 7   Dramas, Independent Movies, International Movies
# 8                       British TV Shows, Reality TV
# 9                                   Comedies, Dramas
# 12                      Dramas, International Movies
# 24   Comedies, International Movies, Romantic Movies
#
#                                           description  s
# 7   On a photo shoot in Ghana, an American model s... -1
# 8   A talented batch of amateur bakers face off in...  2
# 9   A woman adjusting to life after a loss contend... -1
# 12  After most of her family is murdered in a terr... -1
# 24  When the father of the man she loves insists t... -1

# %% [markdown]
# Counting the duration with the value of seasons

# %%
df[df['s'] != -1].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\FL_LPT~1\AppData\Local\Temp/ipykernel_23484/874755681.py in <module>
# ----> 1 df[df['s'] != -1].count()
#
# NameError: name 'df' is not defined

# %% [markdown]
# Question #5: How many movies were released each year.

# %% [markdown]
# Get the all movies from type column and get into movie_year

# %%
movie_year = df[df['type'] == 'Movie']

# %% [markdown]
# Here apply the groupby function on release_year column and calculate the count

# %%
movie_result.groupby(['release_year']).count()
# Out:
#               show_id  type  title  director  cast  country  date_added  \
# release_year
# 1942                1     1      1         1     1        1           1
# 1944                1     1      1         1     1        1           1
# 1945                1     1      1         1     1        1           1
# 1946                1     1      1         1     1        1           1
# 1947                1     1      1         1     1        1           1
# ...               ...   ...    ...       ...   ...      ...         ...
# 2017              640   640    640       640   640      640         640
# 2018              632   632    632       632   632      632         632
# 2019              495   495    495       495   495      495         495
# 2020              409   409    409       409   409      409         409
# 2021              146   146    146       146   146      146         146
#
#               rating  duration  listed_in  description    s
# release_year
# 1942               1         1          1            1    1
# 1944               1         1          1            1    1
# 1945               1         1          1            1    1
# 1946               1         1          1            1    1
# 1947               1         1          1            1    1
# ...              ...       ...        ...          ...  ...
# 2017             640       640        640          640  640
# 2018             632       632        632          632  632
# 2019             495       495        495          495  495
# 2020             409       409        409          409  409
# 2021             146       146        146          146  146
#
# [72 rows x 12 columns]

# %% [markdown]
# Question #6: Which month is the best month to release it.
#
#  Adding a extra colomn as the month column and take the month from date_added column

# %%
df['month'] = pd.DatetimeIndex(df['date_added']).month
df.head()
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin... 2021-09-24
# 8                                      United Kingdom 2021-09-24
# 9                                       United States 2021-09-24
# 12                            Germany, Czech Republic 2021-09-23
# 24                                              India 2021-09-21
#
#     release_year rating   duration  \
# 7           1993  TV-MA    125 min
# 8           2021  TV-14  9 Seasons
# 9           2021  PG-13    104 min
# 12          2021  TV-MA    127 min
# 24          1998  TV-14    166 min
#
#                                            listed_in  \
# 7   Dramas, Independent Movies, International Movies
# 8                       British TV Shows, Reality TV
# 9                                   Comedies, Dramas
# 12                      Dramas, International Movies
# 24   Comedies, International Movies, Romantic Movies
#
#                                           description  s  month
# 7   On a photo shoot in Ghana, an American model s... -1      9
# 8   A talented batch of amateur bakers face off in...  2      9
# 9   A woman adjusting to life after a loss contend... -1      9
# 12  After most of her family is murdered in a terr... -1      9
# 24  When the father of the man she loves insists t... -1      9

# %% [markdown]
#  counting the released Movie from release_year and groupby with month column

# %%
result = df[['month','show_id']].groupby(['month']).count()
result
# Out:
#        show_id
# month
# 1          489
# 2          341
# 3          469
# 4          471
# 5          368
# 6          415
# 7          464
# 8          449
# 9          427
# 10         491
# 11         458
# 12         490

# %%
from matplotlib import pyplot as plt
import numpy as np
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
langs = ['Jan', 'Fab', 'March', 'April', 'May','June','July','Aug','Sep','oct','Nov','Dec']
students = [489,341,469,471,368,415,464,449,427,491,458,490]
ax.pie(students, labels = langs,autopct='%1.2f%%')
plt.show()
